# %% [markdown]
# # Modeling
# ## Predict recommended games
#
# In this part, we will predict if a user would recommend a given game.
#
# I will assume that the goal is to predict the _recommend_ row from the _reviews_ dataset, for a given user and a given game. This is therefore a supervised classification problem.

# %%
cd ..
# Out:
# /Users/nicolas.peruchot/workdir/scalable

# %%
import pandas as pd
import seaborn as sns
from sklearn.model_selection import train_test_split

from steam_challenge.preprocessing.preprocessing_items import items_preprocessing
from steam_challenge.preprocessing.preprocessing_reviews import reviews_preprocessing
from steam_challenge.preprocessing.preprocessing_users import users_preprocessing

from steam_challenge.features_eng import dataset_creation, features_creation
from sklearn.metrics import accuracy_score

pd.options.mode.chained_assignment = None

# %%
reviews=pd.read_json("data/reviews.json",orient='records')
users=pd.read_json("data/users.json",orient='records')
items=pd.read_json("data/items.json",orient='records')

reviews=reviews_preprocessing(reviews)
users=users_preprocessing(users)
items=items_preprocessing(items)

# %% [markdown]
# ## Feature engineering
#
# We will first create the dataset. The goal is to extract features for each game and each user.
#
# - We will first merge the _reviews_ dataset with the _users_ dataset, so that each review is associated to a user.
# - Then, we will create a feature for each game that represent the total playtime for a given game among all users. In the same way, we will determine the total playtime for a given user among all his games. We add these two features to our dataset.
# - Finally, we merge the _items_ dataset to the dataset that we are creating.

# %%
dataset=dataset_creation(reviews=reviews,items=items,users=users)

# %%
Y = dataset.recommend
dataset = dataset.drop(columns=['app_name','recommend','user_id'])

# %%
dataset.head()
# Out:
#                                                           developer  \
# ind
# Game: Carmageddon Max Pack, User: InstigatorAU  Stainless Games Ltd
# Game: Half-Life, User: EizanAratoFujimaki                     Valve
# Game: Half-Life, User: GamerFag                               Valve
# Game: Half-Life, User: 76561198020928326                      Valve
# Game: Half-Life, User: Bluegills                              Valve
#
#                                                 early_access  \
# ind
# Game: Carmageddon Max Pack, User: InstigatorAU             0
# Game: Half-Life, User: EizanAratoFujimaki                  0
# Game: Half-Life, User: GamerFag                            0
# Game: Half-Life, User: 76561198020928326                   0
# Game: Half-Life, User: Bluegills                           0
#
#                                                                        genres  \
# ind
# Game: Carmageddon Max Pack, User: InstigatorAU  ['Action', 'Indie', 'Racing']
# Game: Half-Life, User: EizanAratoFujimaki                          ['Action']
# Game: Half-Life, User: GamerFag                                    ['Action']
# Game: Half-Life, User: 76561198020928326                           ['Action']
# Game: Half-Life, User: Bluegills                                   ['Action']
#
#                                                 price release_date  sentiment  \
# ind
# Game: Carmageddon Max Pack, User: InstigatorAU   9.99   1997-06-30          1
# Game: Half-Life, User: EizanAratoFujimaki        9.99   1998-11-08          1
# Game: Half-Life, User: GamerFag                  9.99   1998-11-08          1
# Game: Half-Life, User: 76561198020928326         9.99   1998-11-08          1
# Game: Half-Life, User: Bluegills                 9.99   1998-11-08          1
#
#                                                                                             specs  \
# ind
# Game: Carmageddon Max Pack, User: InstigatorAU  ['Single-player', 'Multi-player', 'Steam Tradi...
# Game: Half-Life, User: EizanAratoFujimaki       ['Single-player', 'Multi-player', 'Valve Anti-...
# Game: Half-Life, User: GamerFag                 ['Single-player', 'Multi-player', 'Valve Anti-...
# Game: Half-Life, User: 76561198020928326        ['Single-player', 'Multi-player', 'Valve Anti-...
# Game: Half-Life, User: Bluegills                ['Single-player', 'Multi-player', 'Valve Anti-...
#
#                                                                                              tags  \
# ind
# Game: Carmageddon Max Pack, User: InstigatorAU  ['Racing', 'Action', 'Classic', 'Indie', 'Gore...
# Game: Half-Life, User: EizanAratoFujimaki       ['FPS', 'Classic', 'Action', 'Sci-fi', 'Single...
# Game: Half-Life, User: GamerFag                 ['FPS', 'Classic', 'Action', 'Sci-fi', 'Single...
# Game: Half-Life, User: 76561198020928326        ['FPS', 'Classic', 'Action', 'Sci-fi', 'Single...
# Game: Half-Life, User: Bluegills                ['FPS', 'Classic', 'Action', 'Sci-fi', 'Single...
#
#                                                 funny helpful  playtime  \
# ind
# Game: Carmageddon Max Pack, User: InstigatorAU      0       0       466
# Game: Half-Life, User: EizanAratoFujimaki           1      74      1395
# Game: Half-Life, User: GamerFag                     0       0       590
# Game: Half-Life, User: 76561198020928326            0     100      5599
# Game: Half-Life, User: Bluegills                    0       0        64
#
#                                                 Total playtime on Steam for this user  \
# ind
# Game: Carmageddon Max Pack, User: InstigatorAU                                   5678
# Game: Half-Life, User: EizanAratoFujimaki                                        2278
# Game: Half-Life, User: GamerFag                                                 41463
# Game: Half-Life, User: 76561198020928326                                         9324
# Game: Half-Life, User: Bluegills                                                13804
#
#                                                 Total playtime for this game among all users
# ind
# Game: Carmageddon Max Pack, User: InstigatorAU                                           632
# Game: Half-Life, User: EizanAratoFujimaki                                              81542
# Game: Half-Life, User: GamerFag                                                        81542
# Game: Half-Life, User: 76561198020928326                                               81542
# Game: Half-Life, User: Bluegills                                                       81542

# %%
Y.head()
# Out:
# ind
# Game: Carmageddon Max Pack, User: InstigatorAU    True
# Game: Half-Life, User: EizanAratoFujimaki         True
# Game: Half-Life, User: GamerFag                   True
# Game: Half-Life, User: 76561198020928326          True
# Game: Half-Life, User: Bluegills                  True
# Name: recommend, dtype: bool

# %% [markdown]
# ## Baseline model
#
# We will create a first simple baseline model: if the _sentiment_ feature is positive, we will assume that the player is going to recommend the game.

# %%
prediction = [row.sentiment==1 for  _, row in dataset.iterrows()]
score = round(accuracy_score(Y,prediction)*100,2)
print(f"Precision of {score}% on the whole dataset.")
# Out:
# Precision of 84.8% on the whole dataset.

# %% [markdown]
# With this baseline model, the precision is quiet good because our intuition is true: when the majority of the users likes a game, we are more likely to recommend it too.
#
# We will now create a more complex model. For this, we will continue the feature engineering.
# - We will create columns for each _specs_, _genres_ and _tags_.
# - Then, we will encode the name of the developers.
# - We will then normalize the data and reduce the number of features by performing a PCA, keeping 95% of the information.

# %%
dataset=features_creation(data=dataset)

# %%
dataset.head()
# Out:
#                                                      0         1         2    \
# ind
# Game: Carmageddon Max Pack, User: InstigatorAU -1.077378  1.444128 -0.177056
# Game: Half-Life, User: EizanAratoFujimaki      -0.395918  2.547259 -1.460820
# Game: Half-Life, User: GamerFag                -0.329749  2.562931 -1.451227
# Game: Half-Life, User: 76561198020928326       -0.317628  2.572196 -1.471656
# Game: Half-Life, User: Bluegills               -0.416972  2.540017 -1.479670
#
#                                                      3         4         5    \
# ind
# Game: Carmageddon Max Pack, User: InstigatorAU  0.674488 -0.264709  0.032672
# Game: Half-Life, User: EizanAratoFujimaki      -3.506735 -1.944084 -0.189999
# Game: Half-Life, User: GamerFag                -3.514582 -2.007942 -0.274361
# Game: Half-Life, User: 76561198020928326       -3.502447 -2.008656 -0.229122
# Game: Half-Life, User: Bluegills               -3.498658 -1.996057 -0.260199
#
#                                                      6         7         8    \
# ind
# Game: Carmageddon Max Pack, User: InstigatorAU -0.145676  0.641126 -2.324064
# Game: Half-Life, User: EizanAratoFujimaki      -0.798068  1.658398 -1.868825
# Game: Half-Life, User: GamerFag                -0.788192  1.645983 -1.892065
# Game: Half-Life, User: 76561198020928326       -0.795183  1.661691 -1.880534
# Game: Half-Life, User: Bluegills               -0.793537  1.660248 -1.903245
#
#                                                      9    ...       238  \
# ind                                                       ...
# Game: Carmageddon Max Pack, User: InstigatorAU  1.273667  ... -0.960070
# Game: Half-Life, User: EizanAratoFujimaki      -2.502362  ...  0.103976
# Game: Half-Life, User: GamerFag                -2.576678  ...  0.214936
# Game: Half-Life, User: 76561198020928326       -2.562700  ...  0.104554
# Game: Half-Life, User: Bluegills               -2.573462  ...  0.165562
#
#                                                      239       240       241  \
# ind
# Game: Carmageddon Max Pack, User: InstigatorAU -0.210870 -2.588835 -0.626609
# Game: Half-Life, User: EizanAratoFujimaki      -0.666985 -0.883920 -0.165434
# Game: Half-Life, User: GamerFag                -0.650993 -0.899773 -0.258455
# Game: Half-Life, User: 76561198020928326       -0.623620 -0.883542 -0.161348
# Game: Half-Life, User: Bluegills               -0.646142 -0.894077 -0.224047
#
#                                                      242       243       244  \
# ind
# Game: Carmageddon Max Pack, User: InstigatorAU -1.862201  0.952158  0.038417
# Game: Half-Life, User: EizanAratoFujimaki      -0.004997 -0.462682 -1.132751
# Game: Half-Life, User: GamerFag                -0.035552 -0.462567 -1.130320
# Game: Half-Life, User: 76561198020928326       -0.015335 -0.443559 -1.151226
# Game: Half-Life, User: Bluegills               -0.024589 -0.457658 -1.129103
#
#                                                      245       246       247
# ind
# Game: Carmageddon Max Pack, User: InstigatorAU -0.847480  0.439314  1.030504
# Game: Half-Life, User: EizanAratoFujimaki      -0.096305  0.483026 -0.118436
# Game: Half-Life, User: GamerFag                -0.099273  0.453310 -0.088015
# Game: Half-Life, User: 76561198020928326       -0.126525  0.487223 -0.141941
# Game: Half-Life, User: Bluegills               -0.115188  0.475497 -0.101463
#
# [5 rows x 248 columns]

# %% [markdown]
# We will now split our dataset and train a simple Logistic Regression model.

# %%
X_train, X_test, y_train, y_test = train_test_split(dataset,Y,test_size=0.2, random_state=12)

# %%
from sklearn.linear_model import LogisticRegression
lr=LogisticRegression(max_iter=10000)
lr.fit(X_train,y_train)
print(f"Score: {round(accuracy_score(y_test,lr.predict(X_test))*100,2)}")
# Out:
# Score: 89.37

# %% [markdown]
# We now have a better precision on the prediction thanks to our new model.
